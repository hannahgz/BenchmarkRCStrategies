# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahgz/BenchmarkRCStrategies/blob/master/FigGenNew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Binary Prediction Data Files
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_upsample_160.csv -O CTCF_upsample_160.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_upsample_160_half.csv -O CTCF_upsample_160_half.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_160_new.csv -O CTCF_160_new.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_80_new.csv -O CTCF_80_new.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_ISMB_all.csv -O CTCF_ISMB_all.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_train_test.csv -O CTCF_train_test.csv

# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_upsample_160.csv -O MAX_upsample_160.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_upsample_160_half.csv -O MAX_upsample_160_half.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_160_new.csv -O MAX_160_new.csv 
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_80_new.csv -O MAX_80_new.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_ISMB_all.csv -O MAX_ISMB_all.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_train_test.csv -O MAX_train_test.csv

# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_upsample_160.csv -O SPI1_upsample_160.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_upsample_160_half.csv -O SPI1_upsample_160_half.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_160_new.csv -O SPI1_160_new.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_80_new.csv -O SPI1_80_new.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_ISMB_all.csv -O SPI1_ISMB_all.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_train_test.csv -O SPI1_train_test.csv
#Profile Prediction Data Files
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/KLF4_ISMB_test.csv -O KLF4_ISMB_test.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/KLF4_ISMB_train.csv -O KLF4_ISMB_train.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/KLF4_ISMB_loss.csv -O KLF4_ISMB_loss.csv

# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/OCT4_ISMB_test.csv -O OCT4_ISMB_test.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/OCT4_ISMB_train.csv -O OCT4_ISMB_train.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/OCT4_ISMB_loss.csv -O OCT4_ISMB_loss.csv

# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SOX2_ISMB_test.csv -O SOX2_ISMB_test.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SOX2_ISMB_train.csv -O SOX2_ISMB_train.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SOX2_ISMB_loss.csv -O SOX2_ISMB_loss.csv

# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/NANOG_ISMB_test.csv -O NANOG_ISMB_test.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/NANOG_ISMB_train.csv -O NANOG_ISMB_train.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/NANOG_ISMB_loss.csv -O NANOG_ISMB_loss.csv
#Simulated Data Files
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/sim_1000.csv -O sim_1000.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/sim_200.csv -O sim_200.csv

# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/sim_1000_train_test.csv -O sim_1000_train_test.csv
# !wget https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/sim_1000_train_test.csv -O sim_200_train_test.csv
# Out:
# --2021-01-28 01:16:08--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_upsample_160.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16381 (16K) [text/plain]
# Saving to: ‘CTCF_upsample_160.csv’
#
# CTCF_upsample_160.c 100%[===================>]  16.00K  --.-KB/s    in 0.001s
#
# 2021-01-28 01:16:08 (19.3 MB/s) - ‘CTCF_upsample_160.csv’ saved [16381/16381]
#
# --2021-01-28 01:16:08--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_upsample_160_half.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8666 (8.5K) [text/plain]
# Saving to: ‘CTCF_upsample_160_half.csv’
#
# CTCF_upsample_160_h 100%[===================>]   8.46K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:09 (53.1 MB/s) - ‘CTCF_upsample_160_half.csv’ saved [8666/8666]
#
# --2021-01-28 01:16:09--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_160_new.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15078 (15K) [text/plain]
# Saving to: ‘CTCF_160_new.csv’
#
# CTCF_160_new.csv    100%[===================>]  14.72K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:09 (68.6 MB/s) - ‘CTCF_160_new.csv’ saved [15078/15078]
#
# --2021-01-28 01:16:09--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_80_new.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15075 (15K) [text/plain]
# Saving to: ‘CTCF_80_new.csv’
#
# CTCF_80_new.csv     100%[===================>]  14.72K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:09 (69.5 MB/s) - ‘CTCF_80_new.csv’ saved [15075/15075]
#
# --2021-01-28 01:16:09--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_ISMB_all.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6993 (6.8K) [text/plain]
# Saving to: ‘CTCF_ISMB_all.csv’
#
# CTCF_ISMB_all.csv   100%[===================>]   6.83K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:09 (54.5 MB/s) - ‘CTCF_ISMB_all.csv’ saved [6993/6993]
#
# --2021-01-28 01:16:09--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/CTCF_train_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4896 (4.8K) [text/plain]
# Saving to: ‘CTCF_train_test.csv’
#
# CTCF_train_test.csv 100%[===================>]   4.78K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:10 (57.1 MB/s) - ‘CTCF_train_test.csv’ saved [4896/4896]
#
# --2021-01-28 01:16:10--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_upsample_160.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16387 (16K) [text/plain]
# Saving to: ‘MAX_upsample_160.csv’
#
# MAX_upsample_160.cs 100%[===================>]  16.00K  --.-KB/s    in 0.001s
#
# 2021-01-28 01:16:10 (20.4 MB/s) - ‘MAX_upsample_160.csv’ saved [16387/16387]
#
# --2021-01-28 01:16:10--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_upsample_160_half.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8656 (8.5K) [text/plain]
# Saving to: ‘MAX_upsample_160_half.csv’
#
# MAX_upsample_160_ha 100%[===================>]   8.45K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:10 (87.3 MB/s) - ‘MAX_upsample_160_half.csv’ saved [8656/8656]
#
# --2021-01-28 01:16:10--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_160_new.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15081 (15K) [text/plain]
# Saving to: ‘MAX_160_new.csv’
#
# MAX_160_new.csv     100%[===================>]  14.73K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:10 (72.3 MB/s) - ‘MAX_160_new.csv’ saved [15081/15081]
#
# --2021-01-28 01:16:10--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_80_new.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15089 (15K) [text/plain]
# Saving to: ‘MAX_80_new.csv’
#
# MAX_80_new.csv      100%[===================>]  14.74K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:11 (29.0 MB/s) - ‘MAX_80_new.csv’ saved [15089/15089]
#
# --2021-01-28 01:16:11--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_ISMB_all.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6988 (6.8K) [text/plain]
# Saving to: ‘MAX_ISMB_all.csv’
#
# MAX_ISMB_all.csv    100%[===================>]   6.82K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:11 (73.3 MB/s) - ‘MAX_ISMB_all.csv’ saved [6988/6988]
#
# --2021-01-28 01:16:11--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/MAX_train_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4887 (4.8K) [text/plain]
# Saving to: ‘MAX_train_test.csv’
#
# MAX_train_test.csv  100%[===================>]   4.77K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:11 (62.2 MB/s) - ‘MAX_train_test.csv’ saved [4887/4887]
#
# --2021-01-28 01:16:11--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_upsample_160.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16396 (16K) [text/plain]
# Saving to: ‘SPI1_upsample_160.csv’
#
# SPI1_upsample_160.c 100%[===================>]  16.01K  --.-KB/s    in 0.001s
#
# 2021-01-28 01:16:11 (14.6 MB/s) - ‘SPI1_upsample_160.csv’ saved [16396/16396]
#
# --2021-01-28 01:16:11--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_upsample_160_half.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8673 (8.5K) [text/plain]
# Saving to: ‘SPI1_upsample_160_half.csv’
#
# SPI1_upsample_160_h 100%[===================>]   8.47K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:12 (71.0 MB/s) - ‘SPI1_upsample_160_half.csv’ saved [8673/8673]
#
# --2021-01-28 01:16:12--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_160_new.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15085 (15K) [text/plain]
# Saving to: ‘SPI1_160_new.csv’
#
# SPI1_160_new.csv    100%[===================>]  14.73K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:12 (68.7 MB/s) - ‘SPI1_160_new.csv’ saved [15085/15085]
#
# --2021-01-28 01:16:12--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_80_new.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15079 (15K) [text/plain]
# Saving to: ‘SPI1_80_new.csv’
#
# SPI1_80_new.csv     100%[===================>]  14.73K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:12 (86.3 MB/s) - ‘SPI1_80_new.csv’ saved [15079/15079]
#
# --2021-01-28 01:16:12--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_ISMB_all.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6992 (6.8K) [text/plain]
# Saving to: ‘SPI1_ISMB_all.csv’
#
# SPI1_ISMB_all.csv   100%[===================>]   6.83K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:12 (33.7 MB/s) - ‘SPI1_ISMB_all.csv’ saved [6992/6992]
#
# --2021-01-28 01:16:12--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SPI1_train_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4887 (4.8K) [text/plain]
# Saving to: ‘SPI1_train_test.csv’
#
# SPI1_train_test.csv 100%[===================>]   4.77K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:12 (11.0 MB/s) - ‘SPI1_train_test.csv’ saved [4887/4887]
#
# --2021-01-28 01:16:12--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/KLF4_ISMB_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6130 (6.0K) [text/plain]
# Saving to: ‘KLF4_ISMB_test.csv’
#
# KLF4_ISMB_test.csv  100%[===================>]   5.99K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:13 (51.4 MB/s) - ‘KLF4_ISMB_test.csv’ saved [6130/6130]
#
# --2021-01-28 01:16:13--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/KLF4_ISMB_train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2553 (2.5K) [text/plain]
# Saving to: ‘KLF4_ISMB_train.csv’
#
# KLF4_ISMB_train.csv 100%[===================>]   2.49K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:13 (33.6 MB/s) - ‘KLF4_ISMB_train.csv’ saved [2553/2553]
#
# --2021-01-28 01:16:13--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/KLF4_ISMB_loss.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2769 (2.7K) [text/plain]
# Saving to: ‘KLF4_ISMB_loss.csv’
#
# KLF4_ISMB_loss.csv  100%[===================>]   2.70K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:13 (26.2 MB/s) - ‘KLF4_ISMB_loss.csv’ saved [2769/2769]
#
# --2021-01-28 01:16:13--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/OCT4_ISMB_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6068 (5.9K) [text/plain]
# Saving to: ‘OCT4_ISMB_test.csv’
#
# OCT4_ISMB_test.csv  100%[===================>]   5.93K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:13 (57.1 MB/s) - ‘OCT4_ISMB_test.csv’ saved [6068/6068]
#
# --2021-01-28 01:16:14--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/OCT4_ISMB_train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6115 (6.0K) [text/plain]
# Saving to: ‘OCT4_ISMB_train.csv’
#
# OCT4_ISMB_train.csv 100%[===================>]   5.97K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:14 (59.5 MB/s) - ‘OCT4_ISMB_train.csv’ saved [6115/6115]
#
# --2021-01-28 01:16:14--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/OCT4_ISMB_loss.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2769 (2.7K) [text/plain]
# Saving to: ‘OCT4_ISMB_loss.csv’
#
# OCT4_ISMB_loss.csv  100%[===================>]   2.70K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:14 (27.3 MB/s) - ‘OCT4_ISMB_loss.csv’ saved [2769/2769]
#
# --2021-01-28 01:16:14--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SOX2_ISMB_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6142 (6.0K) [text/plain]
# Saving to: ‘SOX2_ISMB_test.csv’
#
# SOX2_ISMB_test.csv  100%[===================>]   6.00K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:14 (62.6 MB/s) - ‘SOX2_ISMB_test.csv’ saved [6142/6142]
#
# --2021-01-28 01:16:14--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SOX2_ISMB_train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6201 (6.1K) [text/plain]
# Saving to: ‘SOX2_ISMB_train.csv’
#
# SOX2_ISMB_train.csv 100%[===================>]   6.06K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:14 (49.9 MB/s) - ‘SOX2_ISMB_train.csv’ saved [6201/6201]
#
# --2021-01-28 01:16:15--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/SOX2_ISMB_loss.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2766 (2.7K) [text/plain]
# Saving to: ‘SOX2_ISMB_loss.csv’
#
# SOX2_ISMB_loss.csv  100%[===================>]   2.70K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:15 (27.5 MB/s) - ‘SOX2_ISMB_loss.csv’ saved [2766/2766]
#
# --2021-01-28 01:16:15--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/NANOG_ISMB_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5823 (5.7K) [text/plain]
# Saving to: ‘NANOG_ISMB_test.csv’
#
# NANOG_ISMB_test.csv 100%[===================>]   5.69K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:15 (43.2 MB/s) - ‘NANOG_ISMB_test.csv’ saved [5823/5823]
#
# --2021-01-28 01:16:15--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/NANOG_ISMB_train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5904 (5.8K) [text/plain]
# Saving to: ‘NANOG_ISMB_train.csv’
#
# NANOG_ISMB_train.cs 100%[===================>]   5.77K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:15 (65.5 MB/s) - ‘NANOG_ISMB_train.csv’ saved [5904/5904]
#
# --2021-01-28 01:16:15--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/NANOG_ISMB_loss.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2763 (2.7K) [text/plain]
# Saving to: ‘NANOG_ISMB_loss.csv’
#
# NANOG_ISMB_loss.csv 100%[===================>]   2.70K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:16 (36.8 MB/s) - ‘NANOG_ISMB_loss.csv’ saved [2763/2763]
#
# --2021-01-28 01:16:16--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/sim_1000.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12594 (12K) [text/plain]
# Saving to: ‘sim_1000.csv’
#
# sim_1000.csv        100%[===================>]  12.30K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:16 (29.6 MB/s) - ‘sim_1000.csv’ saved [12594/12594]
#
# --2021-01-28 01:16:16--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/sim_200.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12589 (12K) [text/plain]
# Saving to: ‘sim_200.csv’
#
# sim_200.csv         100%[===================>]  12.29K  --.-KB/s    in 0s
#
# 2021-01-28 01:16:16 (46.9 MB/s) - ‘sim_200.csv’ saved [12589/12589]
#
# --2021-01-28 01:16:16--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/sim_1000_train_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16735 (16K) [text/plain]
# Saving to: ‘sim_1000_train_test.csv’
#
# sim_1000_train_test 100%[===================>]  16.34K  --.-KB/s    in 0.001s
#
# 2021-01-28 01:16:16 (12.4 MB/s) - ‘sim_1000_train_test.csv’ saved [16735/16735]
#
# --2021-01-28 01:16:16--  https://raw.githubusercontent.com/hannahgz/BenchmarkRCStrategies/master/results/sim_1000_train_test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16735 (16K) [text/plain]
# Saving to: ‘sim_200_train_test.csv’
#
# sim_200_train_test. 100%[===================>]  16.34K  --.-KB/s    in 0.001s
#
# 2021-01-28 01:16:16 (15.4 MB/s) - ‘sim_200_train_test.csv’ saved [16735/16735]

# %%
import matplotlib.pyplot as plt

SMALL_SIZE = 10
MEDIUM_SIZE = 12
BIG_SIZE = 15

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIG_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIG_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIG_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIG_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIG_SIZE)  # fontsize of the figure title

# %% [markdown]
# #Binary Figures

# %% [markdown]
# Binary: Hyperparameter Benchmarking

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def get_pd(dataset, suffix): 
  result = pd.read_csv('%s_%s.csv' % (dataset, str(suffix)))
  result["dataset"] = dataset
  return result

def get_binary_dataset(suffix):
  MAX_dataset = get_pd("MAX", suffix)
  CTCF_dataset = get_pd("CTCF", suffix)
  SPI1_dataset = get_pd("SPI1", suffix)
  return pd.concat([MAX_dataset, CTCF_dataset, SPI1_dataset])

def get_all_binary_data():
  binary_80 = get_binary_dataset("80_new")
  binary_80["Imbalance"] = "classweight"
  binary_80["epochs"] = "maxiter4000"
  binary_160 = get_binary_dataset("160_new")
  binary_160["Imbalance"] = "classweight"
  binary_160["epochs"] = "maxiter8000"
  binary_upsample = get_binary_dataset("upsample_160")
  binary_upsample["Early Stopping Metric"] = "auroc"
  binary_upsample["epochs"] = "maxiter8000"
  
  to_return = pd.concat([binary_80, binary_160, binary_upsample])

  to_return["train_condition"] = (to_return["epochs"]+"_"
        +to_return["Early Stopping Metric"]+"_"+ to_return["Imbalance"])
  
  # to_return["train_condition"] = to_return["train_condition"].replace("maxiter8000_auroc_class_weight", "maxiter8000_auroc_classweight")
  #to_return["train_condition"] = ["maxiter8000_auroc_classweight" if x=="maxiter8000_auroc_class_weight" else x
  #                                for x in to_return["train_condition"]] 


  print(set(to_return['Model Type']))
  #remap the "Model Type" names
  name_remap = {'Standard': 'Standard-NoRCAug',
                'AugWithin': 'Standard-RCAug',
                'RCSumPoolBias': 'RCPS',
                'Siamese': 'CJ-trained',
                'NAugWithin': 'CJ-posthoc'}
  to_return['Model Type'] = [name_remap.get(x, "other") for x
                             in to_return['Model Type']]
  return to_return

def plot_hyperparameter_effect(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  plt.figure(figsize=(20,5))
  filtered_pddataframe = pddataframe[
      (pddataframe["dataset"]==datasetname)
      & (pddataframe["Model Type"].isin(MODEL_TYPES) )
      & (pddataframe["Imbalance"] != "class_weight")]
  
  sns.barplot(data=filtered_pddataframe,
              x="train_condition",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  if (y=="Held-out AuROC"):
    plt.ylabel("AuROC")
  elif (y=="Held-out AuPRC"):
    plt.ylabel("AuPRC")
  plt.title(datasetname)
  plt.ylim(*ylim)

MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS",
               "CJ-trained", "CJ-posthoc"]

binary_data = get_all_binary_data()

# #Lessons: Combo of early stopping using loss and 80 epochs makes Siamese/Aug/NAug look weak (but high variance)
# #With just 80 epochs and early stopping with auroc, AugWithin and NAug look weak but siamese is ok
# #Under upsampling, NAug pulls ahead of Siamese and the others
plot_hyperparameter_effect(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.9, 0.94))
plt.savefig("MAX_hyperparam_AuROC.png", bbox_inches='tight')
#Generally consistent pattern as for auROC
plot_hyperparameter_effect(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.57, 0.745))
plt.savefig("MAX_hyperparam_AuPRC.png", bbox_inches='tight')
#Relative rankings consistent
plot_hyperparameter_effect(datasetname="CTCF",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.965, 0.99))
plt.savefig("CTCF_hyperparam_AuROC.png", bbox_inches='tight')
plot_hyperparameter_effect(datasetname="CTCF",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.93, 0.98))
plt.savefig("CTCF_hyperparam_AuPRC.png", bbox_inches='tight')
#Relative rankings consistent
plot_hyperparameter_effect(datasetname="SPI1",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.98, 0.9925))
plt.savefig("SPI1_hyperparam_AuROC.png", bbox_inches='tight')
plot_hyperparameter_effect(datasetname="SPI1",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.955, 0.985))
plt.savefig("SPI1_hyperparam_AuPRC.png", bbox_inches='tight')
# Out:
# {'Standard', 'Siamese', 'RCWeight', 'AugWithin', 'NAugWithin', 'AugOutDouble', 'NAugOut100', 'NStandard', 'RCSumPoolBias', 'NAugOutDouble', 'RCSumPool', 'AugOut100'}

# %% [markdown]
# Binary: RCPS-half

# %%
MAX_half = pd.read_csv("MAX_upsample_160_half.csv")
CTCF_half = pd.read_csv("CTCF_upsample_160_half.csv")
SPI1_half = pd.read_csv("SPI1_upsample_160_half.csv")


name_remap = {'Standard': 'Standard-NoRCAug',
              'AugWithin': 'Standard-RCAug',
              'RCSumPoolBias': 'RCPS',
              'RCSumPoolBiasHalf': 'RCPS-Half',
              'Siamese': 'CJ-trained',
              'NAugWithin': 'CJ-posthoc'}
              
MAX_half['Model Type'] = [name_remap.get(x, "other") for x
                            in MAX_half['Model Type']]
CTCF_half['Model Type'] = [name_remap.get(x, "other") for x
                            in CTCF_half['Model Type']]
SPI1_half['Model Type'] = [name_remap.get(x, "other") for x
                            in SPI1_half['Model Type']]


def plot_master_figure(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[((pddataframe["Model Type"].isin(MODEL_TYPES)) ) ]

  sns.barplot(data=filtered_pddataframe,
              x="Imbalance",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  plt.ylim(*ylim)
  plt.title(datasetname)
  plt.xlabel("")
  x = []
  plt.xticks(x, " ")


MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS",
              "CJ-trained", "CJ-posthoc", "RCPS-Half"]

fig, ax = plt.subplots(1,3,figsize=(11,5))
fig.suptitle("Benchmarking on Binary TF ChIP-Seq Peak vs. Background Prediction Task", fontsize=14)
fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.91])
plt.axes(ax[0])

plot_master_figure(datasetname="MAX",
                   pddataframe=MAX_half,
                   y="Held-out AuPRC",
                   ylim=(0.64, 0.73))
plt.axes(ax[1])
plot_master_figure(datasetname="CTCF",
                   pddataframe=CTCF_half,
                   y="Held-out AuPRC",
                   ylim=(0.95, 0.98))
plt.axes(ax[2])
plot_master_figure(datasetname="SPI1",
                   pddataframe=SPI1_half,
                   y="Held-out AuPRC",
                   ylim=(0.95, 0.985))

[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuPRC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
plt.savefig("MasterTFBinaryModelsAuPRCHalf.png", bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def get_pd_ISMB(dataset, suffix): 
  result = pd.read_csv('%s_%s.csv' % (dataset, str(suffix)))
  result["dataset"] = dataset
  return result

def get_binary_dataset_ISMB(suffix):
  MAX_dataset = get_pd_ISMB("MAX", suffix)
  CTCF_dataset = get_pd_ISMB("CTCF", suffix)
  SPI1_dataset = get_pd_ISMB("SPI1", suffix)
  pddataframe = pd.concat([MAX_dataset, CTCF_dataset, SPI1_dataset])

  name_remap = {'Standard-NoRCAug': 'Standard-NoRCAug',
                'Standard-RCAug': 'Standard-RCAug',
                'RCPS-Sum': 'RCPS',
                'RCPS-Avg': 'RCPS-Avg',
                'CJ-trained': 'CJ-trained',
                'CJ-trained-max': 'CJ-trained-max',
                'CJ-posthoc': 'CJ-posthoc',
                "CJ-posthoc-postsigmoid": "CJ-posthoc-postsigmoid",  
                'CJRCPS-early': "CJRCWrapper-1,2", 
                "CJRCPS-later": "CJRCWrapper-2,3", 
                "CJRCPS-all": "CJRCWrapper-1,2,3"}
                
  pddataframe['Model Type'] = [name_remap.get(x, "other") for x 
                               in pddataframe['Model Type']] 
  return pddataframe 
  
def get_all_binary_data_ISMB(suffix):
  binary_upsample = get_binary_dataset_ISMB(suffix)
  binary_upsample["Early Stopping Metric"] = "auroc"
  binary_upsample["epochs"] = "maxiter8000"
  binary_upsample["train_condition"] = (binary_upsample["epochs"]+"_"
        +binary_upsample["Early Stopping Metric"]+"_"+ binary_upsample["Imbalance"])
  return binary_upsample


def plot_master_figure(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[((pddataframe["dataset"]==datasetname)
      & (pddataframe["Model Type"].isin(MODEL_TYPES)) 
      & (pddataframe['Imbalance'] == "upsample"))]
  sns.barplot(data=filtered_pddataframe,
              x="train_condition",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  plt.ylim(*ylim)
  plt.title(datasetname)
  plt.xlabel("")
  x = []
  plt.xticks(x, " ")

binary_data = get_all_binary_data_ISMB(suffix = "ISMB_all")

# %% [markdown]
# Binary: Main Figure

# %%
# binary_data = get_all_binary_data_ISMB(suffix = "ISMB_1")
MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS",
                "CJ-trained", "CJ-posthoc"]

fig, ax = plt.subplots(1,3,figsize=(12,5))
fig.suptitle("Benchmarking on Binary TF ChIP-seq Peak vs. Background Prediction Task", fontsize=14)
fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_master_figure(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                          ylim=(0.64, 0.72))
plt.axes(ax[1])
plot_master_figure(datasetname="CTCF",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.95, 0.98))
plt.axes(ax[2])
plot_master_figure(datasetname="SPI1",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.955, 0.985))

[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuPRC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
plt.savefig("MasterTFBinaryModelsAuPRC.png", bbox_inches='tight')

# %% [markdown]
# Binary: Different Merging Strategies

# %%
MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS", "RCPS-Avg",
               "CJ-trained", "CJ-trained-max", 
               "CJ-posthoc", "CJ-posthoc-postsigmoid"]

fig, ax = plt.subplots(1,3,figsize=(20,5))
fig.suptitle("Comparison of Different Representation Merging Strategies for Binary TF ChIP-seq Task", fontsize=14)
fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_master_figure(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.66, 0.72))
                          #  ylim=(0.55, 0.73))
plt.axes(ax[1])
plot_master_figure(datasetname="CTCF",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.955, 0.98))
                          #  ylim=(0.85, 0.98))
plt.axes(ax[2])
plot_master_figure(datasetname="SPI1",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.955, 0.9825))
                          #  ylim=(0.9, 0.9825))
[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuPRC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
plt.savefig("Binary_Merging_Strategies_AuPRC.png", bbox_inches='tight')

# %% [markdown]
# Binary: CJRCWrapper

# %%
MODEL_TYPES = ["RCPS", "RCPS-Avg", "CJ-trained", "CJ-posthoc",
               "CJRCWrapper-1,2", "CJRCWrapper-2,3", "CJRCWrapper-1,2,3"]

fig, ax = plt.subplots(1,3,figsize=(20,5))
fig.suptitle("A Continuum Between RCPS and Conjoined Models for Binary TF ChIP-seq Task", fontsize=14)
fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_master_figure(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.58, 0.72))
                          #  ylim=(0.55, 0.73))
plt.axes(ax[1])
plot_master_figure(datasetname="CTCF",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.85, 0.99))
                          #  ylim=(0.85, 0.98))
plt.axes(ax[2])
plot_master_figure(datasetname="SPI1",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.94, 0.985))
                          #  ylim=(0.9, 0.9825))
[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuPRC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
plt.savefig("Binary_CJRCPS_AuPRC.png", bbox_inches='tight')

# %% [markdown]
# Binary: Test Train

# %%
def plot_profile_figures(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES)) ]
  sns.barplot(data=filtered_pddataframe,
              x="Model Type",
              y=y,
              hue="Train or Test")
  plt.ylim(*ylim)
  plt.title(datasetname)
  # plt.xlabel("")
  # x = []
  # plt.xticks(x, " ")
  
MODEL_TYPES = ["RCPS","CJ-trained", "CJ-posthoc"]

import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
def get_pd_binary_train_test(dataset, suffix): 
  result = pd.read_csv('%s_%s.csv' % (dataset, suffix))
  result["dataset"] = dataset

  #remap the "Model Type" names
  name_remap = {'Standard-NoRCAug': 'Standard-NoRCAug',
                'RCPS': 'RCPS',
                'CJ-duringtraining': 'CJ-trained',
                'RCAug-CJ-posthoc': 'CJ-posthoc'}
  result['Model Type'] = [name_remap.get(x, "other") for x
                             in result['Model Type']]

  return result

CTCF_df = get_pd_binary_train_test("CTCF", "train_test")
MAX_df = get_pd_binary_train_test("MAX", "train_test")
SPI1_df = get_pd_binary_train_test("SPI1", "train_test")

fig, ax = plt.subplots(1,3,figsize=(24,5))
# plt.figure(figsize=(15,10))
fig.suptitle("Comparison of Training vs. Test-Set Performance for RCPS and CJ Architectures for Binary TF ChIP-Seq Peak vs. Background Prediction Task",
             fontsize=15)
y = "Held-out AuROC"
plt.axes(ax[0])
plot_profile_figures(datasetname = "MAX", pddataframe = MAX_df, y = y, ylim = (0.91, 0.965))

plt.axes(ax[1])
plot_profile_figures(datasetname = "CTCF", pddataframe = CTCF_df, y = y, ylim = (0.975, 0.995))

plt.axes(ax[2])
plot_profile_figures(datasetname = "SPI1", pddataframe = SPI1_df, y = y, ylim = (0.988, 0.995))

[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuROC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
plt.savefig("MasterTFBinaryModels_TrainTest_AuROC.png", bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,3,figsize=(24,5))
# plt.figure(figsize=(15,10))
y = "Held-out AuPRC"
fig.suptitle("Benchmarking on Binary TF ChIP-Seq Peak vs. Background Prediction Task", fontsize=13)
plt.axes(ax[0])
plot_profile_figures(datasetname = "MAX", pddataframe = MAX_df, y = y, ylim = (0.65, 0.72))

plt.axes(ax[1])
plot_profile_figures(datasetname = "CTCF", pddataframe = CTCF_df, y = y, ylim = (0.94, 0.985))

plt.axes(ax[2])
plot_profile_figures(datasetname = "SPI1", pddataframe = SPI1_df, y = y, ylim = (0.96, 0.9875))

[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuPRC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]

plt.savefig("MasterTFBinaryModels_TrainTest_AuPRC.png", bbox_inches='tight')

# %% [markdown]
# #Profile Prediction Figures

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
# MODEL_TYPES = ['Standard-NoRCAug', 'Standard-RCAug', 'RCPS', 'RCPS-half', 'CJ-trained', 'CJ-posthoc', 'CJRCWrapper']
def get_pd_profile(dataset, train_or_test): 
  result = pd.read_csv('%s_ISMB_%s.csv' % (dataset, train_or_test))
  result["dataset"] = dataset

  #remap the "Model Type" names
  name_remap = {'Standard-NoRCAug': 'Standard-NoRCAug',
                'Standard-RCAug': 'Standard-RCAug',
                'RCPS': 'RCPS',
                'RCPS-half': 'RCPS-half',
                'CJ-duringtraining': 'CJ-trained',
                'CJ-posthoc': 'CJ-posthoc', 
                'CJRCPS': 'CJRCWrapper'}
  result['Model Type'] = [name_remap.get(x, "other") for x
                             in result['Model Type']]

  return result

OCT4_test_dataset = get_pd_profile(dataset = "OCT4", train_or_test = "test")
SOX2_test_dataset = get_pd_profile(dataset = "SOX2", train_or_test = "test")
KLF4_test_dataset = get_pd_profile(dataset = "KLF4", train_or_test = "test")
NANOG_test_dataset = get_pd_profile(dataset = "NANOG", train_or_test = "test")

OCT4_train_dataset = get_pd_profile(dataset = "OCT4", train_or_test = "train")
SOX2_train_dataset = get_pd_profile(dataset = "SOX2", train_or_test = "train")
KLF4_train_dataset = get_pd_profile(dataset = "KLF4", train_or_test = "train")
NANOG_train_dataset = get_pd_profile(dataset = "NANOG", train_or_test = "train")

OCT4_dataset = pd.concat([OCT4_train_dataset, OCT4_test_dataset])
SOX2_dataset = pd.concat([SOX2_train_dataset, SOX2_test_dataset])
KLF4_dataset = pd.concat([KLF4_train_dataset, KLF4_test_dataset])
NANOG_dataset = pd.concat([NANOG_train_dataset, NANOG_test_dataset])

# %%
def plot_profile_figures(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES)) ]
  sns.barplot(data=filtered_pddataframe,
              x="dataset",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  plt.ylim(*ylim)
  plt.title(datasetname)
  plt.xlabel("")
  x = []
  plt.xticks(x, " ")
  
MODEL_TYPES = ['Standard-NoRCAug', 'Standard-RCAug', 'RCPS', 'CJ-trained', 'CJ-posthoc']

def generate_profile_model_plots(y, friendly_y, ylims, suptitle,
                                 droplegend=False, numrows=4, numcols=20):
  fig, ax = plt.subplots(1,4,figsize=(numcols,numrows))
  # fig, ax = plt.subplots(1,2,figsize=(20,4))
  fig.suptitle(suptitle, fontsize=16)
  fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.91])
  plt.axes(ax[0])
  plot_profile_figures(datasetname = "OCT4", pddataframe = OCT4_test_dataset , y=y, ylim=ylims[0])
  plt.axes(ax[1])
  plot_profile_figures(datasetname = "SOX2", pddataframe = SOX2_test_dataset , y=y, ylim=ylims[1])
  plt.axes(ax[2])
  plot_profile_figures(datasetname = "KLF4", pddataframe = KLF4_test_dataset , y=y, ylim=ylims[2])
  plt.axes(ax[3])
  plot_profile_figures(datasetname = "NANOG",pddataframe = NANOG_test_dataset , y=y, ylim=ylims[3])

  #[x.get_legend().remove() for x in ax[:]]
  if (droplegend):
     [x.get_legend().remove() for x in ax[:]]
  else:
     [x.get_legend().remove() for x in ax[:-1]]
  ax[0].set_ylabel(friendly_y)
  [x.set_ylabel("") for x in ax[1:]]

# %% [markdown]
# Master Profile Figure

# %%
generate_profile_model_plots(y="spear",
                             friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.29,.34),
                                    (0.27,.31),
                                    (0.34,.375),
                                    (0.39,.43)], 
                             suptitle = "Benchmarking on Base-Pair Level ChIP-Nexus Signal Profile Prediction Task",
                             droplegend=True)

plt.savefig("MasterProfileModelsSpearman_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="pears",
                             friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.3,0.4),
                                    (0.35,0.42),
                                    (0.38,0.43),
                                    (0.45,0.70)], 
                             suptitle = "Benchmarking on Base-Pair Level ChIP-Nexus Signal Profile Prediction Task")

plt.savefig("MasterProfileModelsPearson_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="jsd",
                             friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
                             ylims=[(0.155,0.163),
                                    (0.21,0.225),
                                    (0.155,0.164),
                                    (0.14,0.22)], 
                             suptitle = "Benchmarking on Base-Pair Level ChIP-Nexus Signal Profile Prediction Task")

plt.savefig("MasterProfileModelsJSD_ISMB.png", bbox_inches='tight')

# %% [markdown]
# RCPS Half for Profile Prediction

# %%
MODEL_TYPES = ['Standard-NoRCAug', 'Standard-RCAug', 'RCPS', 'RCPS-half', 'CJ-trained', 'CJ-posthoc']

generate_profile_model_plots(y="spear",
                             friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.29,.34),
                                    (0.27,.31),
                                    (0.34,.375),
                                    (0.39,.48)], 
                             suptitle = "Performance Benchmarks of RCPS with Reduced Number of Filters for Base-Pair Level ChIP-Nexus Signal Profile Prediction Task",
                             numrows=5)

plt.savefig("MasterProfileModelsSpearman_RCPS_Half_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="pears",
                             friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.3,0.4),
                                    (0.35,0.42),
                                    (0.38,0.43),
                                    (0.45,0.65)], 
                             suptitle = "Performance Benchmarks of RCPS with Reduced Number of Filters for Base-Pair Level ChIP-Nexus Signal Profile Prediction Task",
                             numrows=5)

plt.savefig("MasterProfileModelsPearson_RCPS_Half_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="jsd",
                             friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
                             ylims=[(0.155,0.164),
                                    (0.21,0.225),
                                    (0.155,0.164),
                                    (0.14,0.20)], 
                             suptitle = "Performance Benchmarks of RCPS with Reduced Number of Filters for Base-Pair Level ChIP-Nexus Signal Profile Prediction Task",
                             numrows=5)

plt.savefig("MasterProfileModelsJSD_RCPS_Half_ISMB.png", bbox_inches='tight')

# %% [markdown]
# CJRCWrapper

# %%
MODEL_TYPES = [#'Standard-NoRCAug', 'Standard-RCAug',
               'RCPS', 'CJ-trained', 'CJ-posthoc', "CJRCWrapper"]
generate_profile_model_plots(y="spear",
                             friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.29,.34),
                                    (0.27,.31),
                                    (0.34,.375),
                                    (0.39,.47)], 
                             suptitle = ("Performance of a Hybrid CJ/RCPS architecture at "
                                         +"Base-Pair Level ChIP-Nexus Signal Profile Prediction Task"),
                             numcols=13)

plt.savefig("MasterProfileModelsSpearman_CJRC_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="pears",
                             friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.3,0.39),
                                    (0.35,0.41),
                                    (0.38,0.43),
                                    (0.45,0.66)], 
                             suptitle = ("Performance of a Hybrid CJ/RCPS architecture at "
                                         +"Base-Pair Level ChIP-Nexus Signal Profile Prediction Task"),
                             numcols=13)

plt.savefig("MasterProfileModelsPearson_CJRC_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="jsd",
                             friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
                             ylims=[(0.155,0.163),
                                    (0.21,0.225),
                                    (0.156,0.164),
                                    (0.14,0.20)], 
                             suptitle = ("Performance of a Hybrid CJ/RCPS architecture at "
                                         +"Base-Pair Level ChIP-Nexus Signal Profile Prediction Task"),
                             numcols=13)

plt.savefig("MasterProfileModelsJSD_CJRC_ISMB.png", bbox_inches='tight')

# %% [markdown]
# Test Train for Profile Prediction with JSD/Spearman/Pearson

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def plot_profile_figures_train_test(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES)) ]
  sns.barplot(data=filtered_pddataframe,
              x="Model Type",
              y=y,
              hue="Train or Test")
  plt.ylim(*ylim)
  plt.title(datasetname)

def generate_profile_model_plots_test_train(y, friendly_y, ylims):
  fig, ax = plt.subplots(1,4,figsize=(20,4))

  fig.suptitle("Comparison of Training vs. Test-Set Performance for RCPS and CJ architectures for Base-Pair Level ChIP-Nexus Signal Profile Prediction Task", fontsize=14)
  fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.91])
  plt.axes(ax[0])
  plot_profile_figures_train_test(datasetname = "OCT4", pddataframe = OCT4_dataset , y=y, ylim=ylims[0])
  plt.axes(ax[1])
  plot_profile_figures_train_test(datasetname = "SOX2", pddataframe = SOX2_dataset , y=y, ylim=ylims[1])
  plt.axes(ax[2])
  plot_profile_figures_train_test(datasetname = "KLF4", pddataframe = KLF4_dataset , y=y, ylim=ylims[2])
  plt.axes(ax[3])
  plot_profile_figures_train_test(datasetname = "NANOG",pddataframe = NANOG_dataset , y=y, ylim=ylims[3])

  if (y=="n/a"):
    [x.get_legend().remove() for x in ax[:]]
  else:
    [x.get_legend().remove() for x in ax[:-1]]
  ax[0].set_ylabel(friendly_y)
  [x.set_ylabel("") for x in ax[1:]]  

  
MODEL_TYPES = ["RCPS","CJ-trained", "CJ-posthoc"]

# %%
generate_profile_model_plots_test_train(y="spear",
                                        friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
                                        ylims=[(0.31,.37),
                                               (0.28,.35),
                                               (0.35,.39),
                                               (0.39,.48)])

plt.savefig("MasterProfileModelsSpearman_Train_Test_ISMB.png", bbox_inches='tight')

generate_profile_model_plots_test_train(y="pears",
                                        friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
                                        ylims=[(0.34,0.43),
                                               (0.36,0.46),
                                               (0.4,0.45),
                                               (0.45,0.64)])

plt.savefig("MasterProfileModelsPearson_Train_Test_ISMB.png", bbox_inches='tight')

generate_profile_model_plots_test_train(y="jsd",
                                        friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
                                        ylims=[(0.145,0.163),
                                                (0.2,0.225),
                                                (0.145,0.162),
                                                (0.14,0.18)])

plt.savefig("MasterProfileModelsJSD_Train_Test_ISMB.png", bbox_inches='tight')

# %% [markdown]
# Test Train for Profile Prediction with Loss

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
# MODEL_TYPES = ['Standard-NoRCAug', 'Standard-RCAug', 'RCPS', 'RCPS-half', 'CJ-trained', 'CJ-posthoc', 'CJRCWrapper']
def get_pd_profile_loss(dataset): 
  result = pd.read_csv('%s_ISMB_loss.csv' % (dataset))
  result["dataset"] = dataset

  #remap the "Model Type" names
  name_remap = {'RCPS': 'RCPS',
                'CJ-duringtraining': 'CJ-trained',
                'CJ-posthoc': 'CJ-posthoc'}
  result['Model Type'] = [name_remap.get(x, "other") for x
                             in result['Model Type']]

  return result

OCT4_loss = get_pd_profile_loss("OCT4")
SOX2_loss = get_pd_profile_loss("SOX2")
NANOG_loss = get_pd_profile_loss("NANOG")
KLF4_loss = get_pd_profile_loss("KLF4")

def plot_profile_figures_train_test_loss(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  sns.barplot(data=pddataframe,
              x="Model Type",
              y=y,
              hue="Train or Test")
  plt.ylim(*ylim)
  plt.title(datasetname)

def generate_profile_model_plots_test_train_loss(y, friendly_y, ylims):
  fig, ax = plt.subplots(1,4,figsize=(20,4))

  fig.suptitle("Comparison of Training vs. Test-Set Performance for RCPS and CJ architectures for Base-Pair Level ChIP-Nexus Signal Profile Prediction Task", fontsize=14)
  fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.91])
  plt.axes(ax[0])
  plot_profile_figures_train_test_loss(datasetname = "OCT4", pddataframe = OCT4_loss , y=y, ylim=ylims[0])
  plt.axes(ax[1])
  plot_profile_figures_train_test_loss(datasetname = "SOX2", pddataframe = SOX2_loss , y=y, ylim=ylims[1])
  plt.axes(ax[2])
  plot_profile_figures_train_test_loss(datasetname = "KLF4", pddataframe = KLF4_loss , y=y, ylim=ylims[2])
  plt.axes(ax[3])
  plot_profile_figures_train_test_loss(datasetname = "NANOG",pddataframe = NANOG_loss , y=y, ylim=ylims[3])

  if (y=="n/a"):
    [x.get_legend().remove() for x in ax[:]]
  else:
    [x.get_legend().remove() for x in ax[:-1]]
  ax[0].set_ylabel(friendly_y)
  [x.set_ylabel("") for x in ax[1:]]  

  
MODEL_TYPES = ["RCPS","CJ-trained", "CJ-posthoc"]
# "Comparison of Training vs. Test-Set Performance for RCPS and CJ Architectures for Binary TF ChIP-Seq Peak vs. Background Prediction Task"

# %%
generate_profile_model_plots_test_train_loss(y="loss",
                                            friendly_y="Loss",
                                            ylims=[(6.35,6.55),
                                                   (6.25,6.55),
                                                   (6.45,6.575),
                                                   (6.05,6.3)])
plt.savefig("MasterProfileModelsLoss_Train_Test_ISMB.png", bbox_inches='tight')

# %% [markdown]
# # Simulated Data

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def get_sim_dataset(seqlen):
  to_return = pd.read_csv("sim_"+str(seqlen)+".csv")
  #remap the "Model Type" names
  print(set(to_return['Model Type']))
  name_remap = {'Standard': 'Standard-NoRCAug',
                'AugWithin': 'Standard-RCAug',
                'RC': 'RCPS',
                'Siamese': 'CJ-trained',
                'NAugWithin': 'CJ-posthoc'}
  to_return['Model Type'] = [name_remap.get(x, "other") for x
                             in to_return['Model Type']]
  return to_return           

sim_200 = get_sim_dataset(200)
sim_1000 = get_sim_dataset(1000)
# Out:
# {'NAugOutside', 'Standard', 'Siamese', 'AugOutside', 'AugWithin', 'AugOutsideDouble', 'NAugOutsideDouble', 'NAugWithin', 'NStandard', 'RC'}
# {'NAugOutside', 'Standard', 'Siamese', 'AugOutside', 'AugWithin', 'AugOutsideDouble', 'NAugOutsideDouble', 'NAugWithin', 'NStandard', 'RC'}

# %%
MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS",
                "CJ-trained", "CJ-posthoc"]

def plot_sim_figures(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES) & 
                                      (pddataframe["Early Stopping Metric"] == "auroc")) ]
  sns.barplot(data=filtered_pddataframe,
              x="Early Stopping Metric",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  plt.ylim(*ylim)
  if (datasetname=="sim 200"):
    plt.title("Sequence Length = 200bp")
  elif (datasetname=="sim 1000"):
    plt.title("Sequence Length = 1000bp")
  plt.xlabel("")
  x = []
  plt.xticks(x, " ")
  plt.ylabel("AuROC (averaged across\nthe 3 output tasks)")
    
  
fig, ax = plt.subplots(1,2,figsize=(8,5))
fig.suptitle("Benchmarking on Simulated Binary Motif Detection Task", fontsize=14)
fig.tight_layout(w_pad=5, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_sim_figures(datasetname = "sim 200", pddataframe = sim_200 , y = "Held-out AuROC", ylim = (0.9,0.98))
ax[0].get_legend().remove()
plt.axes(ax[1])
plot_sim_figures(datasetname = "sim 1000", pddataframe = sim_1000 , y = "Held-out AuROC", ylim = (0.5,0.9))
ax[1].get_legend().remove()

plt.savefig("MasterSimAuROC.png", bbox_inches='tight')

# %% [markdown]
# Simulated Train vs. Test

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def get_sim_train_test_dataset(seqlen):
  to_return = pd.read_csv("sim_"+str(seqlen)+"_train_test.csv")
  #remap the "Model Type" names
  name_remap = {'RCPS': 'RCPS',
                'RC': 'RCPS',
                'Siamese': 'CJ-trained',
                'CJ-trained': 'CJ-trained',
                'NAugWithin': 'CJ-posthoc', 
                'CJ-posthoc': 'CJ-posthoc'}
  to_return['Model Type'] = [name_remap.get(x, "other") for x
                             in to_return['Model Type']]
  return to_return           

sim_train_test_200 = get_sim_train_test_dataset(200)
sim_train_test_1000 = get_sim_train_test_dataset(1000)

MODEL_TYPES = ["RCPS", "CJ-trained", "CJ-posthoc"]

def plot_sim_figures_train_test(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES) & 
                                      (pddataframe["Early Stopping Metric"] == "auroc")) ]
  sns.barplot(data=filtered_pddataframe,
              x="Model Type",
              y=y,
              hue="Train or Test")
  plt.ylim(*ylim)
  if (datasetname=="sim 200"):
    plt.title("Sequence Length = 200bp")
  elif (datasetname=="sim 1000"):
    plt.title("Sequence Length = 1000bp")
  
  plt.ylabel("AuROC (averaged across\nthe 3 output tasks)")

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4))
fig.suptitle("Comparison of Training vs. Test-Set Performance for RCPS and CJ architectures for Simulated Binary Motif Detection Task", fontsize=10)
fig.tight_layout(w_pad=5, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_sim_figures_train_test(datasetname = "sim 200", pddataframe = sim_train_test_200 , y = "Held-out AuROC", ylim = (0.7,0.93))
ax[0].get_legend().remove()
plt.axes(ax[1])
plot_sim_figures_train_test(datasetname = "sim 1000", pddataframe = sim_train_test_1000 , y = "Held-out AuROC", ylim = (0.7,0.93))
# ax[1].get_legend().remove()

plt.savefig("MasterSimAuROC_TrainTest.png", bbox_inches='tight')

# %%
from google.colab import files
import glob
[files.download(x) for x in glob.glob("*.png")]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
