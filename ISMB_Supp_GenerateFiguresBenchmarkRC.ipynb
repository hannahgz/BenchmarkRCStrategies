# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahgz/BenchmarkRCStrategies/blob/master/ISMB_Supp_GenerateFiguresBenchmarkRC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Binary Prediction Data Files
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/CTCF_160_new.csv -O CTCF_160_new.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/CTCF_80_new.csv -O CTCF_80_new.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/CTCF_ISMB_all.csv -O CTCF_ISMB_all.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/CTCF_train_test.csv -O CTCF_train_test.csv

# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/MAX_160_new.csv -O MAX_160_new.csv 
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/MAX_80_new.csv -O MAX_80_new.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/MAX_ISMB_all.csv -O MAX_ISMB_all.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/MAX_train_test.csv -O MAX_train_test.csv

# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SPI1_160_new.csv -O SPI1_160_new.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SPI1_80_new.csv -O SPI1_80_new.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SPI1_ISMB_all.csv -O SPI1_ISMB_all.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SPI1_train_test.csv -O SPI1_train_test.csv

#Profile Prediction Data Files
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/KLF4_ISMB_test.csv -O KLF4_ISMB_test.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/KLF4_ISMB_train.csv -O KLF4_ISMB_train.csv

# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/OCT4_ISMB_test.csv -O OCT4_ISMB_test.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/OCT4_ISMB_train.csv -O OCT4_ISMB_train.csv

# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SOX2_ISMB_test.csv -O SOX2_ISMB_test.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SOX2_ISMB_train.csv -O SOX2_ISMB_train.csv

# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/NANOG_ISMB_test.csv -O NANOG_ISMB_test.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/NANOG_ISMB_train.csv -O NANOG_ISMB_train.csv

#Simulated Data Files
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/sim_1000.csv -O sim_1000.csv
# !wget https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/sim_200.csv -O sim_200.csv
# Out:
# --2021-01-26 17:57:22--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/CTCF_160_new.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘CTCF_160_new.csv’
#
# CTCF_160_new.csv        [ <=>                ] 169.59K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:22 (6.75 MB/s) - ‘CTCF_160_new.csv’ saved [173657]
#
# --2021-01-26 17:57:22--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/CTCF_80_new.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘CTCF_80_new.csv’
#
# CTCF_80_new.csv         [ <=>                ] 169.57K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:23 (7.28 MB/s) - ‘CTCF_80_new.csv’ saved [173635]
#
# --2021-01-26 17:57:23--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/CTCF_ISMB_all.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘CTCF_ISMB_all.csv’
#
# CTCF_ISMB_all.csv       [ <=>                ] 122.66K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:24 (5.39 MB/s) - ‘CTCF_ISMB_all.csv’ saved [125600]
#
# --2021-01-26 17:57:24--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/CTCF_train_test.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘CTCF_train_test.csv’
#
# CTCF_train_test.csv     [ <=>                ] 112.93K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:24 (5.32 MB/s) - ‘CTCF_train_test.csv’ saved [115643]
#
# --2021-01-26 17:57:24--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/MAX_160_new.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘MAX_160_new.csv’
#
# MAX_160_new.csv         [ <=>                ] 169.57K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:24 (7.63 MB/s) - ‘MAX_160_new.csv’ saved [173641]
#
# --2021-01-26 17:57:24--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/MAX_80_new.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘MAX_80_new.csv’
#
# MAX_80_new.csv          [ <=>                ] 169.56K  --.-KB/s    in 0.03s
#
# 2021-01-26 17:57:25 (6.24 MB/s) - ‘MAX_80_new.csv’ saved [173630]
#
# --2021-01-26 17:57:25--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/MAX_ISMB_all.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘MAX_ISMB_all.csv’
#
# MAX_ISMB_all.csv        [ <=>                ] 122.63K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:25 (4.99 MB/s) - ‘MAX_ISMB_all.csv’ saved [125576]
#
# --2021-01-26 17:57:25--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/MAX_train_test.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘MAX_train_test.csv’
#
# MAX_train_test.csv      [ <=>                ] 112.91K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:26 (4.97 MB/s) - ‘MAX_train_test.csv’ saved [115615]
#
# --2021-01-26 17:57:26--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SPI1_160_new.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SPI1_160_new.csv’
#
# SPI1_160_new.csv        [ <=>                ] 169.59K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:26 (7.14 MB/s) - ‘SPI1_160_new.csv’ saved [173664]
#
# --2021-01-26 17:57:26--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SPI1_80_new.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SPI1_80_new.csv’
#
# SPI1_80_new.csv         [ <=>                ] 169.57K  --.-KB/s    in 0.03s
#
# 2021-01-26 17:57:27 (5.32 MB/s) - ‘SPI1_80_new.csv’ saved [173639]
#
# --2021-01-26 17:57:27--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SPI1_ISMB_all.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SPI1_ISMB_all.csv’
#
# SPI1_ISMB_all.csv       [ <=>                ] 122.65K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:27 (5.93 MB/s) - ‘SPI1_ISMB_all.csv’ saved [125595]
#
# --2021-01-26 17:57:27--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SPI1_train_test.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SPI1_train_test.csv’
#
# SPI1_train_test.csv     [ <=>                ] 112.92K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:27 (4.76 MB/s) - ‘SPI1_train_test.csv’ saved [115634]
#
# --2021-01-26 17:57:28--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/KLF4_ISMB_test.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘KLF4_ISMB_test.csv’
#
# KLF4_ISMB_test.csv      [ <=>                ] 116.34K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:28 (5.66 MB/s) - ‘KLF4_ISMB_test.csv’ saved [119131]
#
# --2021-01-26 17:57:28--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/KLF4_ISMB_train.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘KLF4_ISMB_train.csv’
#
# KLF4_ISMB_train.csv     [ <=>                ]  99.24K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:28 (4.13 MB/s) - ‘KLF4_ISMB_train.csv’ saved [101622]
#
# --2021-01-26 17:57:28--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/OCT4_ISMB_test.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘OCT4_ISMB_test.csv’
#
# OCT4_ISMB_test.csv      [ <=>                ] 116.28K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:29 (4.85 MB/s) - ‘OCT4_ISMB_test.csv’ saved [119069]
#
# --2021-01-26 17:57:29--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/OCT4_ISMB_train.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘OCT4_ISMB_train.csv’
#
# OCT4_ISMB_train.csv     [ <=>                ] 116.34K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:29 (4.91 MB/s) - ‘OCT4_ISMB_train.csv’ saved [119135]
#
# --2021-01-26 17:57:29--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SOX2_ISMB_test.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SOX2_ISMB_test.csv’
#
# SOX2_ISMB_test.csv      [ <=>                ] 116.35K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:29 (5.14 MB/s) - ‘SOX2_ISMB_test.csv’ saved [119140]
#
# --2021-01-26 17:57:30--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/SOX2_ISMB_train.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SOX2_ISMB_train.csv’
#
# SOX2_ISMB_train.csv     [ <=>                ] 116.43K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:30 (5.32 MB/s) - ‘SOX2_ISMB_train.csv’ saved [119221]
#
# --2021-01-26 17:57:30--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/NANOG_ISMB_test.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘NANOG_ISMB_test.csv’
#
# NANOG_ISMB_test.csv     [ <=>                ] 114.46K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:30 (5.07 MB/s) - ‘NANOG_ISMB_test.csv’ saved [117212]
#
# --2021-01-26 17:57:30--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/NANOG_ISMB_train.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘NANOG_ISMB_train.csv’
#
# NANOG_ISMB_train.cs     [ <=>                ] 114.56K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:31 (4.65 MB/s) - ‘NANOG_ISMB_train.csv’ saved [117312]
#
# --2021-01-26 17:57:31--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/sim_1000.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sim_1000.csv’
#
# sim_1000.csv            [ <=>                ] 155.84K  --.-KB/s    in 0.03s
#
# 2021-01-26 17:57:31 (5.95 MB/s) - ‘sim_1000.csv’ saved [159577]
#
# --2021-01-26 17:57:31--  https://github.com/hannahgz/BenchmarkRCStrategies/blob/master/results/sim_200.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sim_200.csv’
#
# sim_200.csv             [ <=>                ] 155.81K  --.-KB/s    in 0.02s
#
# 2021-01-26 17:57:32 (6.58 MB/s) - ‘sim_200.csv’ saved [159553]

# %%
import matplotlib.pyplot as plt

SMALL_SIZE = 10
MEDIUM_SIZE = 12
BIG_SIZE = 15

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIG_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIG_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIG_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIG_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIG_SIZE)  # fontsize of the figure title

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def get_pd(dataset, suffix): 
  result = pd.read_csv('%s_%s.csv' % (dataset, str(suffix)))
  result["dataset"] = dataset
  return result

def get_binary_dataset(suffix):
  MAX_dataset = get_pd("MAX", suffix)
  CTCF_dataset = get_pd("CTCF", suffix)
  SPI1_dataset = get_pd("SPI1", suffix)
  return pd.concat([MAX_dataset, CTCF_dataset, SPI1_dataset])

def get_all_binary_data():
  binary_80 = get_binary_dataset("80_new")
  binary_80["Imbalance"] = "classweight"
  binary_80["epochs"] = "maxiter4000"
  binary_160 = get_binary_dataset("160_new")
  binary_160["Imbalance"] = "classweight"
  binary_160["epochs"] = "maxiter8000"
  binary_upsample = get_binary_dataset("upsample_160")
  binary_upsample["Early Stopping Metric"] = "auroc"
  binary_upsample["epochs"] = "maxiter8000"
  
  to_return = pd.concat([binary_80, binary_160, binary_upsample])

  to_return["train_condition"] = (to_return["epochs"]+"_"
        +to_return["Early Stopping Metric"]+"_"+ to_return["Imbalance"])
  
  # to_return["train_condition"] = to_return["train_condition"].replace("maxiter8000_auroc_class_weight", "maxiter8000_auroc_classweight")
  #to_return["train_condition"] = ["maxiter8000_auroc_classweight" if x=="maxiter8000_auroc_class_weight" else x
  #                                for x in to_return["train_condition"]] 


  print(set(to_return['Model Type']))
  #remap the "Model Type" names
  # name_remap = {'Standard': 'Standard-NoRCAug',
  #               'AugWithin': 'Standard-RCAug',
  #               'RCSumPoolBias': 'RCPS',
  #               'Siamese': 'CJ-trained',
  #               'NAugWithin': 'CJ-posthoc'}
  # to_return['Model Type'] = [name_remap.get(x, "other") for x
  #                            in to_return['Model Type']]
  return to_return

def plot_hyperparameter_effect(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  plt.figure(figsize=(20,5))
  filtered_pddataframe = pddataframe[
      (pddataframe["dataset"]==datasetname)
      & (pddataframe["Model Type"].isin(MODEL_TYPES) )
      & (pddataframe["Imbalance"] != "class_weight")]
  
  sns.barplot(data=filtered_pddataframe,
              x="train_condition",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  if (y=="Held-out AuROC"):
    plt.ylabel("AuROC")
  elif (y=="Held-out AuPRC"):
    plt.ylabel("AuPRC")
  plt.title(datasetname)
  plt.ylim(*ylim)

MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS",
               "CJ-duringtraining", "RCAug-CJ-posthoc"]

#MODEL_TYPES = ["Standard", "RCSumPool", "Siamese", "AugWithin", "NAugWithin"]
binary_data = get_all_binary_data()

# #Lessons: Combo of early stopping using loss and 80 epochs makes Siamese/Aug/NAug look weak (but high variance)
# #With just 80 epochs and early stopping with auroc, AugWithin and NAug look weak but siamese is ok
# #Under upsampling, NAug pulls ahead of Siamese and the others
plot_hyperparameter_effect(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.9, 0.94))
plt.savefig("MAX_hyperparam_AuROC.png", bbox_inches='tight')
#Generally consistent pattern as for auROC
plot_hyperparameter_effect(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.57, 0.745))
plt.savefig("MAX_hyperparam_AuPRC.png", bbox_inches='tight')
#Relative rankings consistent
plot_hyperparameter_effect(datasetname="CTCF",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.965, 0.99))
plt.savefig("CTCF_hyperparam_AuROC.png", bbox_inches='tight')
plot_hyperparameter_effect(datasetname="CTCF",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.93, 0.98))
plt.savefig("CTCF_hyperparam_AuPRC.png", bbox_inches='tight')
#Relative rankings consistent
plot_hyperparameter_effect(datasetname="SPI1",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.98, 0.9925))
plt.savefig("SPI1_hyperparam_AuROC.png", bbox_inches='tight')
plot_hyperparameter_effect(datasetname="SPI1",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.955, 0.985))
plt.savefig("SPI1_hyperparam_AuPRC.png", bbox_inches='tight')
# Out:
# {'Siamese', 'NAugWithin', 'RCSumPoolBias', 'AugOut100', 'AugOutDouble', 'Standard', 'AugWithin', 'NAugOut100', 'NStandard', 'RCWeight', 'NAugOutDouble', 'RCSumPool'}

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def get_pd_ISMB(dataset, suffix): 
  result = pd.read_csv('%s_%s.csv' % (dataset, str(suffix)))
  result["dataset"] = dataset
  return result

def get_binary_dataset_ISMB(suffix):
  MAX_dataset = get_pd_ISMB("MAX", suffix)
  CTCF_dataset = get_pd_ISMB("CTCF", suffix)
  SPI1_dataset = get_pd_ISMB("SPI1", suffix)
  pddataframe = pd.concat([MAX_dataset, CTCF_dataset, SPI1_dataset])

  name_remap = {'Standard-NoRCAug': 'Standard-NoRCAug',
              'Standard-RCAug': 'Standard-RCAug',
              'RCPS-Sum': 'RCPS',
              'RCPS-Avg': 'RCPS-Avg',
              'CJ-trained': 'CJ-trained',
              'CJ-trained-max': 'CJ-trained-max',
              'CJ-posthoc': 'CJ-posthoc',
              "CJ-posthoc-postsigmoid": "CJ-posthoc-postsigmoid",  
              'CJRCPS-early': "CJRCWrapper-1,2", 
              "CJRCPS-later": "CJRCWrapper-2,3", 
              "CJRCPS-all": "CJRCWrapper-1,2,3"}
                
  pddataframe['Model Type'] = [name_remap.get(x, "other") for x 
                               in pddataframe['Model Type']] 
  return pddataframe 
  
def get_all_binary_data_ISMB(suffix):
  binary_upsample = get_binary_dataset_ISMB(suffix)
  binary_upsample["Early Stopping Metric"] = "auroc"
  binary_upsample["epochs"] = "maxiter8000"
  binary_upsample["train_condition"] = (binary_upsample["epochs"]+"_"
        +binary_upsample["Early Stopping Metric"]+"_"+ binary_upsample["Imbalance"])
  return binary_upsample

# %%
# binary_data = get_all_binary_data_ISMB(suffix = "ISMB_1")
# MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS",
#                "CJ-trained", "CJ-trained-max", "CJ-posthoc"]
binary_data = get_all_binary_data_ISMB(suffix = "ISMB_all")
# MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS-Sum", 
#                "RCPS-Avg", "CJ-trained", "CJ-trained-max", 
#                "CJ-posthoc", "CJ-posthoc-postsigmoid", 
#                "CJRCPS-early", "CJRCPS-later", "CJRCPS-all"]
MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS", "RCPS-Avg",
               "CJ-trained", "CJ-trained-max", 
               "CJ-posthoc", "CJ-posthoc-postsigmoid"]

def plot_master_figure(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[((pddataframe["dataset"]==datasetname)
      & (pddataframe["Model Type"].isin(MODEL_TYPES)) 
      & (pddataframe['Imbalance'] == "upsample"))]
  sns.barplot(data=filtered_pddataframe,
              x="train_condition",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  plt.ylim(*ylim)
  plt.title(datasetname)
  plt.xlabel("")
  x = []
  plt.xticks(x, " ")


fig, ax = plt.subplots(1,3,figsize=(20,5))
fig.suptitle("Comparison of Different Representation Merging Strategies for Binary TF ChIP-seq Task", fontsize=14)
fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_master_figure(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.66, 0.72))
                          #  ylim=(0.55, 0.73))
plt.axes(ax[1])
plot_master_figure(datasetname="CTCF",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.95, 0.98))
                          #  ylim=(0.85, 0.98))
plt.axes(ax[2])
plot_master_figure(datasetname="SPI1",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.965, 0.9825))
                          #  ylim=(0.9, 0.9825))
[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuPRC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
plt.savefig("Binary_Merging_Strategies_AuPRC.png", bbox_inches='tight')

# %%
# binary_data
# Out:
#      Unnamed: 0  ...             train_condition
# 0             0  ...  maxiter8000_auroc_upsample
# 1             1  ...  maxiter8000_auroc_upsample
# 2             2  ...  maxiter8000_auroc_upsample
# 3             3  ...  maxiter8000_auroc_upsample
# 4             4  ...  maxiter8000_auroc_upsample
# ..          ...  ...                         ...
# 105         105  ...  maxiter8000_auroc_upsample
# 106         106  ...  maxiter8000_auroc_upsample
# 107         107  ...  maxiter8000_auroc_upsample
# 108         108  ...  maxiter8000_auroc_upsample
# 109         109  ...  maxiter8000_auroc_upsample
#
# [330 rows x 9 columns]

# %%
# name_remap = {'Standard-NoRCAug': 'Standard-NoRCAug',
#               'Standard-RCAug': 'Standard-RCAug',
#               'RCPS-Sum': 'RCPS',
#               'RCPS-Avg': 'RCPS-Avg',
#               'CJ-trained': 'CJ-trained',
#               'CJ-trained-max': 'CJ-trained-max',
#               'CJ-posthoc': 'CJ-posthoc',
#               "CJ-posthoc-postsigmoid": "CJ-posthoc-postsigmoid",  
#               'CJRCPS-early': "CJRCWrapper-1,2", 
#               "CJRCPS-later": "CJRCWrapper-2,3", 
#               "CJRCPS-all": "CJRCWrapper-1,2,3"}
# #   # print(pddataframe.to_string())
# binary_data['Model Type'] = [name_remap.get(x, "other") for x 
#                               in binary_data['Model Type']]

# %%
# MODEL_TYPES = ["RCPS", "RCPS-Avg", "CJ-trained", "CJ-posthoc",
#                "CJRCWrapper-1,2", "CJRCWrapper-2,3", "CJRCWrapper-1,2,3"]
# filtered_pddataframe = binary_data[((binary_data["dataset"]=="CTCF")
#     & (binary_data["Model Type"].isin(MODEL_TYPES)) 
#     & (binary_data['Imbalance'] == "upsample"))]

# %%
# filtered_pddataframe
# Out:
#      Unnamed: 0         Model Type  ...       epochs             train_condition
# 2             2               RCPS  ...  maxiter8000  maxiter8000_auroc_upsample
# 3             3           RCPS-Avg  ...  maxiter8000  maxiter8000_auroc_upsample
# 4             4         CJ-trained  ...  maxiter8000  maxiter8000_auroc_upsample
# 6             6         CJ-posthoc  ...  maxiter8000  maxiter8000_auroc_upsample
# 8             8    CJRCWrapper-1,2  ...  maxiter8000  maxiter8000_auroc_upsample
# ..          ...                ...  ...          ...                         ...
# 103         103         CJ-trained  ...  maxiter8000  maxiter8000_auroc_upsample
# 105         105         CJ-posthoc  ...  maxiter8000  maxiter8000_auroc_upsample
# 107         107    CJRCWrapper-1,2  ...  maxiter8000  maxiter8000_auroc_upsample
# 108         108    CJRCWrapper-2,3  ...  maxiter8000  maxiter8000_auroc_upsample
# 109         109  CJRCWrapper-1,2,3  ...  maxiter8000  maxiter8000_auroc_upsample
#
# [70 rows x 9 columns]

# %%
# sns.barplot(data=filtered_pddataframe,
#           x="train_condition",
#           y="Held-out AuPRC",
#           hue="Model Type",
#           hue_order=MODEL_TYPES)

# %%
# binary_data = get_all_binary_data_ISMB(suffix = "ISMB_1")
# MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS",
#                "CJ-trained", "CJ-trained-max", "CJ-posthoc"]
binary_data = get_all_binary_data_ISMB(suffix = "ISMB_all")
# MODEL_TYPES = ["Standard-NoRCAug", "Standard-RCAug", "RCPS-Sum", 
#                "RCPS-Avg", "CJ-trained", "CJ-trained-max", 
#                "CJ-posthoc", "CJ-posthoc-postsigmoid", 
#                "CJRCPS-early", "CJRCPS-later", "CJRCPS-all"]
MODEL_TYPES = ["RCPS", "RCPS-Avg", "CJ-trained", "CJ-posthoc",
               "CJRCWrapper-1,2", "CJRCWrapper-2,3", "CJRCWrapper-1,2,3"]

fig, ax = plt.subplots(1,3,figsize=(20,5))
fig.suptitle("A Continuum Between RCPS and Conjoined Models for Binary TF ChIP-seq Task", fontsize=14)
fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_master_figure(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuPRC",
                           ylim=(0.58, 0.72))
                          #  ylim=(0.55, 0.73))
plt.axes(ax[1])
plot_master_figure(datasetname="CTCF",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.85, 0.99))
                          #  ylim=(0.85, 0.98))
plt.axes(ax[2])
plot_master_figure(datasetname="SPI1",
                   pddataframe=binary_data,
                   y="Held-out AuPRC",
                   ylim=(0.94, 0.985))
                          #  ylim=(0.9, 0.9825))
[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuPRC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
plt.savefig("Binary_CJRCPS_AuPRC.png", bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,3,figsize=(20,4.2))
fig.suptitle("Benchmarking on Binary TF ChIP-Seq Peak vs. Background Prediction Task", fontsize=14)
fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_master_figure(datasetname="MAX",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.88, 0.935))
plt.axes(ax[1])
plot_master_figure(datasetname="CTCF",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.92, 0.992))
plt.axes(ax[2])
plot_master_figure(datasetname="SPI1",
                           pddataframe=binary_data,
                           y="Held-out AuROC",
                           ylim=(0.96, 0.993))
[x.get_legend().remove() for x in ax[1:]]
ax[0].set_ylabel("AuROC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
# plt.savefig("retrain-CJRCPS-new-all-avg-AuROC.png", bbox_inches='tight')

# %% [markdown]
# #Profile Prediction Figures

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
# MODEL_TYPES = ['Standard-NoRCAug', 'Standard-RCAug', 'RCPS', 'RCPS-half', 'CJ-trained', 'CJ-posthoc', 'CJRCWrapper']
def get_pd_profile(dataset, train_or_test): 
  result = pd.read_csv('%s_ISMB_%s.csv' % (dataset, train_or_test))
  result["dataset"] = dataset

  #remap the "Model Type" names
  name_remap = {'Standard-NoRCAug': 'Standard-NoRCAug',
                'Standard-RCAug': 'Standard-RCAug',
                'RCPS': 'RCPS',
                'RCPS-half': 'RCPS-half',
                'CJ-duringtraining': 'CJ-trained',
                'CJ-posthoc': 'CJ-posthoc', 
                'CJRCPS': 'CJRCWrapper'}
  result['Model Type'] = [name_remap.get(x, "other") for x
                             in result['Model Type']]

  return result

OCT4_test_dataset = get_pd_profile(dataset = "OCT4", train_or_test = "test")
SOX2_test_dataset = get_pd_profile(dataset = "SOX2", train_or_test = "test")
KLF4_test_dataset = get_pd_profile(dataset = "KLF4", train_or_test = "test")
NANOG_test_dataset = get_pd_profile(dataset = "NANOG", train_or_test = "test")

OCT4_train_dataset = get_pd_profile(dataset = "OCT4", train_or_test = "train")
SOX2_train_dataset = get_pd_profile(dataset = "SOX2", train_or_test = "train")
KLF4_train_dataset = get_pd_profile(dataset = "KLF4", train_or_test = "train")
NANOG_train_dataset = get_pd_profile(dataset = "NANOG", train_or_test = "train")

OCT4_dataset = pd.concat([OCT4_train_dataset, OCT4_test_dataset])
SOX2_dataset = pd.concat([SOX2_train_dataset, SOX2_test_dataset])
KLF4_dataset = pd.concat([KLF4_train_dataset, KLF4_test_dataset])
NANOG_dataset = pd.concat([NANOG_train_dataset, NANOG_test_dataset])

# %%
NANOG_dataset
# Out:
#     Unnamed: 0        Model Type  seed  ...     spear  Train or Test  dataset
# 0            0  Standard-NoRCAug  1535  ...  0.434934          train    NANOG
# 1            1    Standard-RCAug  1535  ...  0.430237          train    NANOG
# 2            2              RCPS  1535  ...  0.426779          train    NANOG
# 3            3        CJ-trained  1535  ...  0.439620          train    NANOG
# 4            4        CJ-posthoc  1535  ...  0.436786          train    NANOG
# ..         ...               ...   ...  ...       ...            ...      ...
# 65          65              RCPS  9295  ...  0.412511           test    NANOG
# 66          66        CJ-trained  9295  ...  0.411390           test    NANOG
# 67          67        CJ-posthoc  9295  ...  0.420430           test    NANOG
# 68          68         RCPS-half  9295  ...  0.414049           test    NANOG
# 69          69       CJRCWrapper  9295  ...  0.412982           test    NANOG
#
# [140 rows x 8 columns]

# %%
def plot_profile_figures(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES)) ]
  sns.barplot(data=filtered_pddataframe,
              x="dataset",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  plt.ylim(*ylim)
  plt.title(datasetname)
  plt.xlabel("")
  x = []
  plt.xticks(x, " ")
  

# #MODEL_TYPES = ["Standard", "AugWithin", "RevComp", "Siamese", "NAugWithin"]
# MODEL_TYPES = ['Standard-NoRCAug', 'Standard-RCAug', 'RCPS', 'CJ-trained', 'CJ-posthoc']
# def generate_profile_model_plots(y, friendly_y, ylims):
#   fig, ax = plt.subplots(1,4,figsize=(20,4))
#   # fig, ax = plt.subplots(1,2,figsize=(20,4))
#   fig.suptitle("Benchmarking on Base-Pair Level ChIP-Nexus Signal Profile Prediction Task", fontsize=14)
#   fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
#   plt.axes(ax[0])
#   plot_profile_figures(datasetname = "OCT4", pddataframe = OCT4_dataset , y=y, ylim=ylims[0])
#   plt.axes(ax[1])
#   plot_profile_figures(datasetname = "SOX2", pddataframe = SOX2_dataset , y=y, ylim=ylims[1])
#   plt.axes(ax[2])
#   plot_profile_figures(datasetname = "KLF4", pddataframe = KLF4_dataset , y=y, ylim=ylims[2])
#   plt.axes(ax[3])
#   plot_profile_figures(datasetname = "NANOG",pddataframe = NANOG_dataset , y=y, ylim=ylims[3])

#   if (y=="spear"):
#     [x.get_legend().remove() for x in ax[:]]
#   else:
#     [x.get_legend().remove() for x in ax[:-1]]
#   ax[0].set_ylabel(friendly_y)
#   [x.set_ylabel("") for x in ax[1:]]
# generate_profile_model_plots(y="spear",
#                              friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
#                              ylims=[(0.29,.34),
#                                     (0.27,.31),
#                                     (0.34,.375),
#                                     (0.39,.43)])

# plt.savefig("MasterProfileModelsSpearman_ISMB.png", bbox_inches='tight')

# generate_profile_model_plots(y="pears",
#                              friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
#                              ylims=[(0.3,0.4),
#                                     (0.35,0.42),
#                                     (0.38,0.43),
#                                     (0.45,0.65)])

# plt.savefig("MasterProfileModelsPearson_ISMB.png", bbox_inches='tight')

# generate_profile_model_plots(y="jsd",
#                              friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
#                              ylims=[(0.155,0.163),
#                                     (0.21,0.225),
#                                     (0.155,0.164),
#                                     (0.14,0.22)])

# plt.savefig("MasterProfileModelsJSD_ISMB.png", bbox_inches='tight')

# %% [markdown]
# RCPS Half for Profile Prediction

# %%
MODEL_TYPES = ['Standard-NoRCAug', 'Standard-RCAug', 'RCPS', 'RCPS-half', 'CJ-trained', 'CJ-posthoc']
def generate_profile_model_plots(y, friendly_y, ylims):
  fig, ax = plt.subplots(1,4,figsize=(20,4))
  # fig, ax = plt.subplots(1,2,figsize=(20,4))
  fig.suptitle("Performance Benchmarks of RCPS with Reduced Number of Filters for Base-Pair Level ChIP-Nexus Signal Profile Prediction Task", fontsize=14)
  fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
  plt.axes(ax[0])
  plot_profile_figures(datasetname = "OCT4", pddataframe = OCT4_dataset , y=y, ylim=ylims[0])
  plt.axes(ax[1])
  plot_profile_figures(datasetname = "SOX2", pddataframe = SOX2_dataset , y=y, ylim=ylims[1])
  plt.axes(ax[2])
  plot_profile_figures(datasetname = "KLF4", pddataframe = KLF4_dataset , y=y, ylim=ylims[2])
  plt.axes(ax[3])
  plot_profile_figures(datasetname = "NANOG",pddataframe = NANOG_dataset , y=y, ylim=ylims[3])

  if (y=="n/a"):
    [x.get_legend().remove() for x in ax[:]]
  else:
    [x.get_legend().remove() for x in ax[:-1]]
  ax[0].set_ylabel(friendly_y)
  [x.set_ylabel("") for x in ax[1:]]
generate_profile_model_plots(y="spear",
                             friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.29,.34),
                                    (0.27,.31),
                                    (0.34,.375),
                                    (0.39,.5)])

plt.savefig("MasterProfileModelsSpearman_RCPS_Half_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="pears",
                             friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.3,0.4),
                                    (0.35,0.42),
                                    (0.38,0.43),
                                    (0.45,0.65)])

plt.savefig("MasterProfileModelsPearson_RCPS_Half_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="jsd",
                             friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
                             ylims=[(0.155,0.164),
                                    (0.21,0.225),
                                    (0.155,0.164),
                                    (0.14,0.22)])

plt.savefig("MasterProfileModelsJSD_RCPS_Half_ISMB.png", bbox_inches='tight')

# %% [markdown]
# CJRCWrapper

# %%
MODEL_TYPES = ['Standard-NoRCAug', 'Standard-RCAug', 'RCPS', 'CJ-trained', 'CJ-posthoc', "CJRCWrapper"]
def generate_profile_model_plots(y, friendly_y, ylims):
  fig, ax = plt.subplots(1,4,figsize=(20,4))
  # fig, ax = plt.subplots(1,2,figsize=(20,4))
  fig.suptitle("A Continuum Between RCPS and Conjoined Models for Base-Pair Level ChIP-Nexus Signal Profile Prediction Task", fontsize=14)
  fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
  plt.axes(ax[0])
  plot_profile_figures(datasetname = "OCT4", pddataframe = OCT4_test_dataset , y=y, ylim=ylims[0])
  plt.axes(ax[1])
  plot_profile_figures(datasetname = "SOX2", pddataframe = SOX2_test_dataset , y=y, ylim=ylims[1])
  plt.axes(ax[2])
  plot_profile_figures(datasetname = "KLF4", pddataframe = KLF4_test_dataset , y=y, ylim=ylims[2])
  plt.axes(ax[3])
  plot_profile_figures(datasetname = "NANOG",pddataframe = NANOG_test_dataset , y=y, ylim=ylims[3])

  if (y=="n/a"):
    [x.get_legend().remove() for x in ax[:]]
  else:
    [x.get_legend().remove() for x in ax[:-1]]
  ax[0].set_ylabel(friendly_y)
  [x.set_ylabel("") for x in ax[1:]]
generate_profile_model_plots(y="spear",
                             friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.29,.34),
                                    (0.27,.31),
                                    (0.34,.375),
                                    (0.39,.5)])

plt.savefig("MasterProfileModelsSpearman_CJRC_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="pears",
                             friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.3,0.39),
                                    (0.35,0.41),
                                    (0.38,0.43),
                                    (0.45,0.66)])

plt.savefig("MasterProfileModelsPearson_CJRC_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="jsd",
                             friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
                             ylims=[(0.155,0.163),
                                    (0.21,0.225),
                                    (0.156,0.164),
                                    (0.14,0.23)])

plt.savefig("MasterProfileModelsJSD_CJRC_ISMB.png", bbox_inches='tight')

# %% [markdown]
# Test Train for Profile Prediction

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def plot_profile_figures_train_test(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES)) ]
  sns.barplot(data=filtered_pddataframe,
              x="Model Type",
              y=y,
              hue="Train or Test")
  plt.ylim(*ylim)
  plt.title(datasetname)

def generate_profile_model_plots(y, friendly_y, ylims):
  fig, ax = plt.subplots(1,4,figsize=(20,4))

  fig.suptitle("Comparison of Training vs. Test-Set Performance for RCPS and CJ architectures for Base-Pair Level ChIP-Nexus Signal Profile Prediction Task", fontsize=14)
  fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
  plt.axes(ax[0])
  plot_profile_figures_train_test(datasetname = "OCT4", pddataframe = OCT4_dataset , y=y, ylim=ylims[0])
  plt.axes(ax[1])
  plot_profile_figures_train_test(datasetname = "SOX2", pddataframe = SOX2_dataset , y=y, ylim=ylims[1])
  plt.axes(ax[2])
  plot_profile_figures_train_test(datasetname = "KLF4", pddataframe = KLF4_dataset , y=y, ylim=ylims[2])
  plt.axes(ax[3])
  plot_profile_figures_train_test(datasetname = "NANOG",pddataframe = NANOG_dataset , y=y, ylim=ylims[3])

  if (y=="n/a"):
    [x.get_legend().remove() for x in ax[:]]
  else:
    [x.get_legend().remove() for x in ax[:-1]]
  ax[0].set_ylabel(friendly_y)
  [x.set_ylabel("") for x in ax[1:]]  

  
MODEL_TYPES = ["RCPS","CJ-trained", "CJ-posthoc"]

# %%
generate_profile_model_plots(y="spear",
                             friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.31,.37),
                                    (0.28,.35),
                                    (0.35,.39),
                                    (0.39,.48)])

plt.savefig("MasterProfileModelsSpearman_Train_Test_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="pears",
                             friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
                             ylims=[(0.34,0.43),
                                    (0.36,0.46),
                                    (0.4,0.45),
                                    (0.45,0.64)])

plt.savefig("MasterProfileModelsPearson_Train_Test_ISMB.png", bbox_inches='tight')

generate_profile_model_plots(y="jsd",
                             friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
                             ylims=[(0.145,0.163),
                                    (0.2,0.225),
                                    (0.145,0.162),
                                    (0.14,0.18)])

plt.savefig("MasterProfileModelsJSD_Train_Test_ISMB.png", bbox_inches='tight')

# %% [markdown]
# # Simulated Data

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

def get_sim_dataset(seqlen):
  to_return = pd.read_csv("sim_"+str(seqlen)+".csv")
  #remap the "Model Type" names
  print(set(to_return['Model Type']))
  name_remap = {'Standard': 'Standard-NoRCAug',
                'AugWithin': 'Standard-RCAug',
                'RC': 'RCPS',
                'Siamese': 'CJ-trained',
                'NAugWithin': 'CJ-posthoc'}
  to_return['Model Type'] = [name_remap.get(x, "other") for x
                             in to_return['Model Type']]
  return to_return           

sim_200 = get_sim_dataset(200)
sim_1000 = get_sim_dataset(1000)
# Out:
# {'AugOutside', 'NAugOutside', 'NStandard', 'Standard', 'NAugWithin', 'Siamese', 'AugOutsideDouble', 'AugWithin', 'NAugOutsideDouble', 'RC'}
# {'AugOutside', 'NAugOutside', 'NStandard', 'Standard', 'NAugWithin', 'Siamese', 'AugOutsideDouble', 'AugWithin', 'NAugOutsideDouble', 'RC'}

# %%
def plot_sim_figures(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES) & 
                                      (pddataframe["Early Stopping Metric"] == "auroc")) ]
  sns.barplot(data=filtered_pddataframe,
              x="Early Stopping Metric",
              y=y,
              hue="Model Type",
              hue_order=MODEL_TYPES)
  plt.ylim(*ylim)
  if (datasetname=="sim 200"):
    plt.title("Sequence Length = 200bp")
  elif (datasetname=="sim 1000"):
    plt.title("Sequence Length = 1000bp")
  plt.xlabel("")
  x = []
  plt.xticks(x, " ")
  plt.ylabel("AuROC (averaged across\nthe 3 output tasks)")
    
  
fig, ax = plt.subplots(1,2,figsize=(12,5))
fig.suptitle("Benchmarking on Simulated Binary Motif Detection Task", fontsize=14)
fig.tight_layout(w_pad=5, rect=[0, 0, 1, 0.93])
plt.axes(ax[0])
plot_sim_figures(datasetname = "sim 200", pddataframe = sim_200 , y = "Held-out AuROC", ylim = (0.9,0.98))
plt.axes(ax[1])
plot_sim_figures(datasetname = "sim 1000", pddataframe = sim_1000 , y = "Held-out AuROC", ylim = (0.5,0.9))
ax[1].get_legend().remove()

plt.savefig("MasterSimAuROC.png", bbox_inches='tight')

# %%
from google.colab import files
import glob
[files.download(x) for x in glob.glob("*.png")]
# Out:
# [None, None, None, None, None, None, None]

# %% [markdown]
# # TRAIN TEST BENCHMARKING

# %% [markdown]
# Binary Models

# %%
def plot_profile_figures(datasetname, pddataframe, y, ylim):
  #filter for the dataset
  filtered_pddataframe = pddataframe[(pddataframe["Model Type"].isin(MODEL_TYPES)) ]
  sns.barplot(data=filtered_pddataframe,
              x="Model Type",
              y=y,
              hue="Train or Test")
  plt.ylim(*ylim)
  plt.title(datasetname)
  # plt.xlabel("")
  # x = []
  # plt.xticks(x, " ")
  
MODEL_TYPES = ["RCPS","CJ-trained", "CJ-posthoc"]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
def get_pd_binary_train_test(dataset, suffix): 
  result = pd.read_csv('%s_%s.csv' % (dataset, suffix))
  result["dataset"] = dataset

  #remap the "Model Type" names
  name_remap = {'Standard-NoRCAug': 'Standard-NoRCAug',
                'RCPS': 'RCPS',
                'CJ-duringtraining': 'CJ-trained',
                'RCAug-CJ-posthoc': 'CJ-posthoc'}
  result['Model Type'] = [name_remap.get(x, "other") for x
                             in result['Model Type']]

  return result

# %%
CTCF_df = get_pd_binary_train_test("CTCF", "train_test")
MAX_df = get_pd_binary_train_test("MAX", "train_test")
SPI1_df = get_pd_binary_train_test("SPI1", "train_test")

# %%
fig, ax = plt.subplots(1,3,figsize=(24,4))
# plt.figure(figsize=(15,10))
fig.suptitle("Benchmarking on Binary TF ChIP-Seq Peak vs. Background Prediction Task", fontsize=13)
y = "Held-out AuROC"
plt.axes(ax[0])
plot_profile_figures(datasetname = "MAX", pddataframe = MAX_df, y = y, ylim = (0.91, 0.965))

plt.axes(ax[1])
plot_profile_figures(datasetname = "CTCF", pddataframe = CTCF_df, y = y, ylim = (0.975, 0.995))

plt.axes(ax[2])
plot_profile_figures(datasetname = "SPI1", pddataframe = SPI1_df, y = y, ylim = (0.988, 0.995))

[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuROC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]
plt.savefig("MasterTFBinaryModels_TrainTest_AuROC.png", bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,3,figsize=(24,4))
# plt.figure(figsize=(15,10))
y = "Held-out AuPRC"
fig.suptitle("Benchmarking on Binary TF ChIP-Seq Peak vs. Background Prediction Task", fontsize=13)
plt.axes(ax[0])
plot_profile_figures(datasetname = "MAX", pddataframe = MAX_df, y = y, ylim = (0.65, 0.72))

plt.axes(ax[1])
plot_profile_figures(datasetname = "CTCF", pddataframe = CTCF_df, y = y, ylim = (0.94, 0.985))

plt.axes(ax[2])
plot_profile_figures(datasetname = "SPI1", pddataframe = SPI1_df, y = y, ylim = (0.96, 0.9875))

[x.get_legend().remove() for x in ax[:-1]]
ax[0].set_ylabel("AuPRC of Binary Models")
[x.set_ylabel("") for x in ax[1:]]

plt.savefig("MasterTFBinaryModels_TrainTest_AuPRC.png", bbox_inches='tight')

# %% [markdown]
# PROFILE MODELS - IGNORE

# %%
##ON OLD INPUT GENERATOR


# import seaborn as sns
# from matplotlib import pyplot as plt
# import pandas as pd

# def get_pd_profile(dataset, suffix): 
#   result = pd.read_csv('%s_%s.csv' % (dataset, suffix))
#   result["dataset"] = dataset

#   #remap the "Model Type" names
#   name_remap = {'Standard': 'Standard-NoRCAug',
#                 'AugWithin': 'Standard-RCAug',
#                 'RevComp': 'RCPS',
#                 'RCPS': 'RCPS',
#                 'Siamese': 'CJ-trained',
#                 'NAugWithin': 'CJ-posthoc'}
#   result['Model Type'] = [name_remap.get(x, "other") for x
#                              in result['Model Type']]

#   return result

# OCT4_test_dataset = get_pd_profile("OCT4", "new_metrics")
# OCT4_test_dataset["Train or Test"] = "test"
# SOX2_test_dataset = get_pd_profile("SOX2", "new_metrics")
# SOX2_test_dataset["Train or Test"] = "test"
# KLF4_test_dataset = get_pd_profile("KLF4", "new_metrics")
# KLF4_test_dataset["Train or Test"] = "test"
# NANOG_test_dataset = get_pd_profile("NANOG", "new_metrics")
# NANOG_test_dataset["Train or Test"] = "test"


# OCT4_train_dataset = get_pd_profile("OCT4", "train")
# OCT4_train_dataset["Train or Test"] = "train"
# SOX2_train_dataset = get_pd_profile("SOX2", "train")
# SOX2_train_dataset["Train or Test"] = "train"
# KLF4_train_dataset = get_pd_profile("KLF4", "train")
# KLF4_train_dataset["Train or Test"] = "train"
# NANOG_train_dataset = get_pd_profile("NANOG", "train")
# NANOG_train_dataset["Train or Test"] = "train"

# OCT4_full_dataset = pd.concat([OCT4_test_dataset, OCT4_train_dataset])
# SOX2_full_dataset = pd.concat([SOX2_test_dataset, SOX2_train_dataset])
# KLF4_full_dataset = pd.concat([KLF4_test_dataset, KLF4_train_dataset])
# NANOG_full_dataset = pd.concat([NANOG_test_dataset, NANOG_train_dataset])

# def generate_profile_model_plots(y, friendly_y, ylims):
#   fig, ax = plt.subplots(1,4,figsize=(24,4))
#   fig.suptitle("Benchmarking on Base-Pair Level ChIP-Nexus Signal Profile Prediction Task", fontsize=14)
#   fig.tight_layout(w_pad=2, rect=[0, 0, 1, 0.93])
#   plt.axes(ax[0])
#   plot_profile_figures(datasetname = "OCT4", pddataframe = OCT4_full_dataset , y=y, ylim=ylims[0])
#   plt.axes(ax[1])
#   plot_profile_figures(datasetname = "SOX2", pddataframe = SOX2_full_dataset , y=y, ylim=ylims[1])
#   plt.axes(ax[2])
#   plot_profile_figures(datasetname = "KLF4", pddataframe = KLF4_full_dataset , y=y, ylim=ylims[2])
#   plt.axes(ax[3])
#   plot_profile_figures(datasetname = "NANOG",pddataframe = NANOG_full_dataset , y=y, ylim=ylims[3])

#   if (y=="x"):
#     [x.get_legend().remove() for x in ax[:]]
#   else:
#     [x.get_legend().remove() for x in ax[:-1]]
#   ax[0].set_ylabel(friendly_y)
#   [x.set_ylabel("") for x in ax[1:]]

# generate_profile_model_plots(y="spear",
#                              friendly_y="Spearman Correlation\nof Predicted vs. True Profile",
#                              ylims=[(0.29,.37),
#                                     (0.27,.35),
#                                     (0.34,.39),
#                                     (0.39,.45)])

# plt.savefig("MasterProfileModelsSpearmanTestTrain.png", bbox_inches='tight')

# generate_profile_model_plots(y="pears",
#                              friendly_y="Pearson Correlation\nof Predicted vs. True Profile",
#                              ylims=[(0.3,0.42),
#                                     (0.35,0.47),
#                                     (0.38,0.45),
#                                     (0.45,0.58)])

# plt.savefig("MasterProfileModelsPearsonTestTrain.png", bbox_inches='tight')

# generate_profile_model_plots(y="jsd",
#                              friendly_y="Jenson-Shannon Divergence\nof Predicted vs. True Profile",
#                              ylims=[(0.13,0.17),
#                                     (0.19,0.23),
#                                     (0.12,0.167),
#                                     (0.14,0.17)])

# plt.savefig("MasterProfileModelsJSDTestTrain.png", bbox_inches='tight')

# %%
OCT4_full_dataset
# Out:
#     Unnamed: 0        Model Type  seed  ...     spear  dataset  Train or Test
# 0            0              RCPS  1535  ...  0.308800     OCT4           test
# 1            1        CJ-trained  1535  ...  0.320566     OCT4           test
# 2            2  Standard-NoRCAug  1535  ...  0.316436     OCT4           test
# 3            3    Standard-RCAug  1535  ...  0.329217     OCT4           test
# 4            4        CJ-posthoc  1535  ...  0.337424     OCT4           test
# ..         ...               ...   ...  ...       ...      ...            ...
# 45          45  Standard-NoRCAug  9295  ...  0.353761     OCT4          train
# 46          46    Standard-RCAug  9295  ...  0.353262     OCT4          train
# 47          47             other  9295  ...  0.316484     OCT4          train
# 48          48        CJ-trained  9295  ...  0.367570     OCT4          train
# 49          49        CJ-posthoc  9295  ...  0.361880     OCT4          train
#
# [150 rows x 8 columns]
